# %%
import os
import zipfile
import time
import pickle
import gc

import pandas as pd
import numpy as np
from tqdm import tqdm

from utils import load_pickle, dump_pickle, get_feature_value, feature_spearmanr, feature_target_spearmanr, addCrossFeature, calibration
from utils import raw_data_path, feature_data_path, cache_pkl_path, analyse

from sklearn.metrics import log_loss
import lightgbm as lgb

# %%
all_data_path = feature_data_path + 'all_data_all_features.pkl'
all_data = load_pickle(all_data_path)

# %%
target = 'is_trade'

features = load_pickle('all_features_day_7.pkl')
categorical_feature = load_pickle('categorical_feature.pkl')

# 只使用原始特征
# features = load_pickle('original_features.pkl')
# categorical_feature = ['user_gender_id', 'user_occupation_id']

len(features), len(categorical_feature)

# %% [markdown]
# ### 取7号上午数据进行训练和测试，以11点为分割

# %%
data = all_data[(all_data.day == 7) & (all_data.is_trade != -1)]
# train_data = data[(data.hour < 11)]
# test_data = data[data.hour >= 11]

train_data = data[(data.hour < 11) & (data.hour > 1)]
# train_data = data[(data.hour < 11) & (data.hour > 1) | ((data.hour == 1)&(data.minute >=30))]
test_data = data[data.hour >= 11]

# data = all_data[(all_data.is_trade != -1)]
# train_data = data[((data.day == 6) & (data.hour > 20)) | ((data.hour < 11) & (data.day == 7))]
# test_data = data[(data.hour >= 11) & (data.day == 7)]

lgb_train_data = lgb.Dataset(
    train_data[features], label=train_data[target], feature_name=features, categorical_feature=categorical_feature)
lgb_test_data = lgb_train_data.create_valid(
    test_data[features], label=test_data[target])

print(train_data.shape)
print(test_data.shape)

# %%
param = {'application': 'binary',
         'metric': 'binary_logloss',

         'learning_rate': 0.05,

         'max_depth': 5,
         'num_leaves': 18,

         'min_data_in_leaf': 100,
         'min_sum_hessian_in_leaf': 0.01,
         'min_gain_to_split': 0.1,

         'feature_fraction': 0.9,
         'bagging_fraction': 0.7,
         'bagging_freq': 1,

         'lambda_l2': 10,
         'max_bin': 63,

         'device': 'gpu',
         'gpu_use_dp': True,
         }


valid_sets = [lgb_train_data, lgb_test_data]

bst = lgb.train(param, lgb_train_data, valid_sets=valid_sets, 
                num_boost_round=2000, 
                early_stopping_rounds=300, 
                verbose_eval=50, 
                categorical_feature=categorical_feature
               )

# %%
predict_train = bst.predict(train_data[features])
predict_test = bst.predict(test_data[features])

train_ctr = float(sum(predict_train)/float(len(predict_train)))
test_ctr = float(sum(predict_test)/float(len(predict_test)))
train_ctr, test_ctr
# Out:
# (0.04577492183308594, 0.04448399618933612)

# %% [markdown]
# ## 特征重要度

# %%
importance = pd.DataFrame(bst.feature_importance())
importance.columns = ['importance_20']
features = pd.DataFrame(features)
features.columns = ['features_20']
pd.set_option('max_rows',500)
merge = features.join(importance)
merge = merge.sort_values(by=['importance_20'], ascending=False).reset_index()
merge
# Out:
#      index                                        features_20  importance_20
# 0       76                          user_click_time_gap_after            336
# 1       46                           item_property_topic_k_10            276
# 2      127           user_age_level_item_sales_level_hour_CTR            269
# 3      158                                 item_id_smooth_CTR            217
# 4       14                                            shop_id            201
# 5       20                             shop_score_description            198
# 6        0                                            item_id            195
# 7        7                                            user_id            182
# 8      244                                 item_id_click_hour            174
# 9       19                                shop_score_delivery            172
# 10       1                                      item_brand_id            170
# 11      11                                    user_star_level            161
# 12     153                                   user_id_smooth_I            161
# 13      79       user_category2_label_last_click_interval_day            155
# 14       4                                   item_sales_level            152
# 15       2                                       item_city_id            149
# 16     211                 item_id_user_star_level_click_rate            144
# 17       5                               item_collected_level            135
# 18      73                      user_click_interval_first_day            134
# 19     209                  item_id_user_age_level_click_rate            132
# 20      74                       user_click_interval_last_day            132
# 21     249                                 shop_id_click_hour            130
# 22     208                  item_id_user_gender_id_click_rate            127
# 23     134       user_occupation_id_item_sales_level_hour_CTR            125
# 24     248                         context_page_id_click_hour            122
# 25     205                  shop_id_user_age_level_click_rate            121
# 26      81      user_category2_label_click_time_gap_after_day            119
# 27     204                  shop_id_user_gender_id_click_rate            119
# 28      15                              shop_review_num_level            119
# 29     173                                 shop_id_smooth_CTR            118
# 30      65                             user_id_click_day_mean            118
# 31     207                 shop_id_user_star_level_click_rate            117
# 32     193                  user_gender_id_item_id_smooth_CTR            115
# 33      18                                 shop_score_service            115
# 34     131            user_age_level_category2_label_hour_CTR            115
# 35     163                           category2_label_smooth_C            114
# 36     197            user_age_level_item_brand_id_smooth_CTR            114
# 37     118                              category_predict_rank            111
# 38     196                  user_age_level_item_id_smooth_CTR            111
# 39     161                           item_brand_id_smooth_CTR            109
# 40     215           item_brand_id_user_star_level_click_rate            109
# 41     212            item_brand_id_user_gender_id_click_rate            109
# 42      12                                  context_timestamp            107
# 43     202                 user_star_level_item_id_smooth_CTR            106
# 44     156                                   item_id_smooth_I            106
# 45      16                          shop_review_positive_rate            104
# 46     199              user_occupation_id_item_id_smooth_CTR            103
# 47      75                         user_click_time_gap_before            102
# 48      69                             item_id_click_day_mean            102
# 49     149            user_gender_id_user_star_level_hour_CTR            102
# 50     206              shop_id_user_occupation_id_click_rate            102
# 51      26                     user_gender_id_category2_label            100
# 52      30                     user_age_level_category2_label            100
# 53     172                                   shop_id_smooth_C             98
# 54     192                  user_gender_id_shop_id_smooth_CTR             97
# 55     241                                  shop_id_click_day             93
# 56     151            user_age_level_user_star_level_hour_CTR             93
# 57      38                    user_star_level_category2_label             92
# 58     141          user_star_level_item_sales_level_hour_CTR             92
# 59     250                item_property_topic_k_10_click_hour             91
# 60     142           user_star_level_shop_star_level_hour_CTR             88
# 61     237                                  item_id_click_day             87
# 62      96              user_item_id_click_time_gap_after_day             87
# 63     120           user_gender_id_item_sales_level_hour_CTR             87
# 64     171                                   shop_id_smooth_I             87
# 65     198              user_occupation_id_shop_id_smooth_CTR             86
# 66     143     user_star_level_shop_review_num_level_hour_CTR             86
# 67     195                  user_age_level_shop_id_smooth_CTR             85
# 68      17                                    shop_star_level             85
# 69     164                         category2_label_smooth_CTR             85
# 70     138        user_occupation_id_category2_label_hour_CTR             85
# 71     210              item_id_user_occupation_id_click_rate             84
# 72     122      user_gender_id_shop_review_num_level_hour_CTR             83
# 73     130  user_age_level_shop_review_positive_rate_hour_CTR             83
# 74     214        item_brand_id_user_occupation_id_click_rate             83
# 75     117                                       property_sim             82
# 76      95             user_item_id_click_time_gap_before_day             82
# 77     136  user_occupation_id_shop_review_num_level_hour_CTR             82
# 78      68                             shop_id_click_day_mean             81
# 79     203           user_star_level_item_brand_id_smooth_CTR             81
# 80     245                           item_brand_id_click_hour             80
# 81     155                                 user_id_smooth_CTR             79
# 82      37                   user_star_level_item_sales_level             78
# 83     144  user_star_level_shop_review_positive_rate_hour...             78
# 84     145           user_star_level_category2_label_hour_CTR             78
# 85     246                         category2_label_click_hour             78
# 86     146           user_star_level_category3_label_hour_CTR             77
# 87      47                     user_category2_label_click_day             77
# 88     227                    hour_user_star_level_click_rate             77
# 89     125            user_gender_id_category3_label_hour_CTR             76
# 90      84       user_category3_label_last_click_interval_day             76
# 91      83      user_category3_label_first_click_interval_day             76
# 92     194            user_gender_id_item_brand_id_smooth_CTR             75
# 93     157                                   item_id_smooth_C             75
# 94     231    item_sales_level_bin_user_star_level_click_rate             74
# 95     140          user_star_level_item_price_level_hour_CTR             73
# 96     219         category2_label_user_star_level_click_rate             73
# 97     139        user_occupation_id_category3_label_hour_CTR             73
# 98     116                              item_property_topic_9             72
# 99     235    item_price_level_bin_user_star_level_click_rate             72
# 100    124            user_gender_id_category2_label_hour_CTR             72
# 101    183                          user_id_item_id_history_I             72
# 102     86      user_category3_label_click_time_gap_after_day             72
# 103    152        user_occupation_id_user_star_level_hour_CTR             72
# 104    135        user_occupation_id_shop_star_level_hour_CTR             71
# 105    213            item_brand_id_user_age_level_click_rate             71
# 106    106  user_item_property_topic_k_10_click_time_gap_a...             71
# 107    223         category3_label_user_star_level_click_rate             70
# 108    128            user_age_level_shop_star_level_hour_CTR             69
# 109    126           user_age_level_item_price_level_hour_CTR             69
# 110    133       user_occupation_id_item_price_level_hour_CTR             68
# 111    201                 user_star_level_shop_id_smooth_CTR             68
# 112     35                 user_occupation_id_category3_label             67
# 113    229     item_sales_level_bin_user_age_level_click_rate             67
# 114    236                                  user_id_click_day             66
# 115    132            user_age_level_category3_label_hour_CTR             66
# 116    113                              item_property_topic_6             65
# 117     92                        user_item_id_click_rank_day             65
# 118     34                 user_occupation_id_category2_label             65
# 119    121            user_gender_id_shop_star_level_hour_CTR             64
# 120    251                        user_item_id_continue_click             63
# 121     40                      user_gender_id_user_age_level             63
# 122     29                    user_age_level_item_sales_level             62
# 123     31                     user_age_level_category3_label             62
# 124    238                            item_brand_id_click_day             62
# 125     66                     category2_label_click_day_mean             62
# 126    137  user_occupation_id_shop_review_positive_rate_h...             61
# 127     70                       item_brand_id_click_day_mean             61
# 128     94               user_item_id_last_click_interval_day             61
# 129     80     user_category2_label_click_time_gap_before_day             60
# 130     22                                    category2_label             60
# 131     13                                    context_page_id             59
# 132    216          category2_label_user_gender_id_click_rate             59
# 133    104  user_item_property_topic_k_10_last_click_inter...             58
# 134     25                    user_gender_id_item_sales_level             58
# 135     24                    user_gender_id_item_price_level             58
# 136    261                   user_category3_label_future_2min             58
# 137    200        user_occupation_id_item_brand_id_smooth_CTR             58
# 138      6                                      item_pv_level             58
# 139     39                    user_star_level_category3_label             57
# 140    175                      item_sales_level_bin_smooth_C             57
# 141    218      category2_label_user_occupation_id_click_rate             56
# 142    119           user_gender_id_item_price_level_hour_CTR             56
# 143     71                     context_page_id_click_day_mean             56
# 144     33                user_occupation_id_item_sales_level             56
# 145    226                 hour_user_occupation_id_click_rate             56
# 146    243                                 user_id_click_hour             55
# 147     44                     user_age_level_user_star_level             55
# 148    129      user_age_level_shop_review_num_level_hour_CTR             55
# 149    110                              item_property_topic_3             54
# 150      9                                     user_age_level             54
# 151    160                             item_brand_id_smooth_C             53
# 152    225                     hour_user_age_level_click_rate             52
# 153    105  user_item_property_topic_k_10_click_time_gap_b...             52
# 154     28                    user_age_level_item_price_level             52
# 155    112                              item_property_topic_5             51
# 156    123  user_gender_id_shop_review_positive_rate_hour_CTR             51
# 157    150         user_age_level_user_occupation_id_hour_CTR             51
# 158     93              user_item_id_first_click_interval_day             50
# 159    103  user_item_property_topic_k_10_first_click_inte...             50
# 160     48                     user_category3_label_click_day             50
# 161    228     item_sales_level_bin_user_gender_id_click_rate             49
# 162    254                user_category2_label_continue_click             49
# 163    247                         category3_label_click_hour             49
# 164    147             user_gender_id_user_age_level_hour_CTR             49
# 165     54                user_item_price_level_bin_click_day             49
# 166    184                    user_id_item_brand_id_history_I             48
# 167    224                     hour_user_gender_id_click_rate             47
# 168     85     user_category3_label_click_time_gap_before_day             47
# 169     77                user_category2_label_click_rank_day             47
# 170    186                  user_id_category3_label_history_I             46
# 171    230  item_sales_level_bin_user_occupation_id_click_...             45
# 172    221          category3_label_user_age_level_click_rate             45
# 173     78      user_category2_label_first_click_interval_day             45
# 174    148         user_gender_id_user_occupation_id_hour_CTR             45
# 175    114                              item_property_topic_7             45
# 176    258           user_item_price_level_bin_continue_click             44
# 177    255                user_category3_label_continue_click             44
# 178    217          category2_label_user_age_level_click_rate             44
# 179    159                             item_brand_id_smooth_I             43
# 180      3                                   item_price_level             43
# 181     88              user_shop_id_first_click_interval_day             43
# 182     52                     user_context_page_id_click_day             43
# 183    190             user_id_item_price_level_bin_history_I             42
# 184     23                                    category3_label             41
# 185    109                              item_property_topic_2             41
# 186     32                user_occupation_id_item_price_level             40
# 187     61                    user_context_page_id_click_hour             40
# 188     36                   user_star_level_item_price_level             38
# 189     42                     user_gender_id_user_star_level             38
# 190     53            user_item_property_topic_k_10_click_day             38
# 191    260                  user_category2_label_future_15min             37
# 192    166                           category3_label_smooth_C             37
# 193    232     item_price_level_bin_user_gender_id_click_rate             36
# 194    115                              item_property_topic_8             36
# 195     27                     user_gender_id_category3_label             36
# 196    185                  user_id_category2_label_history_I             35
# 197     57                    user_category3_label_click_hour             35
# 198     72                                user_click_rank_day             34
# 199    167                         category3_label_smooth_CTR             34
# 200     82                user_category3_label_click_rank_day             34
# 201    108                              item_property_topic_1             33
# 202    233     item_price_level_bin_user_age_level_click_rate             33
# 203    256       user_item_property_topic_k_10_continue_click             33
# 204     56                    user_category2_label_click_hour             32
# 205    187                          user_id_shop_id_history_I             32
# 206    259                   user_category2_label_future_2min             31
# 207     99         user_item_brand_id_last_click_interval_day             31
# 208    222      category3_label_user_occupation_id_click_rate             30
# 209    174                      item_sales_level_bin_smooth_I             30
# 210     50                             user_item_id_click_day             30
# 211    111                              item_property_topic_4             29
# 212     43                  user_age_level_user_occupation_id             29
# 213    234  item_price_level_bin_user_occupation_id_click_...             28
# 214    220          category3_label_user_gender_id_click_rate             28
# 215    176                    item_sales_level_bin_smooth_CTR             28
# 216     90             user_shop_id_click_time_gap_before_day             27
# 217    191           user_id_item_price_level_bin_history_CTR             27
# 218     87                        user_shop_id_click_rank_day             26
# 219    262                  user_category3_label_future_15min             26
# 220    107                              item_property_topic_0             25
# 221     98        user_item_brand_id_first_click_interval_day             25
# 222    267          user_item_property_topic_k_10_future_2min             25
# 223     67                     category3_label_click_day_mean             24
# 224     63               user_item_price_level_bin_click_hour             24
# 225     45                 user_occupation_id_user_star_level             24
# 226     62           user_item_property_topic_k_10_click_hour             24
# 227     55                user_item_sales_level_bin_click_day             22
# 228    188             user_id_item_sales_level_bin_history_I             20
# 229    252                  user_item_brand_id_continue_click             19
# 230    270              user_item_price_level_bin_future_2min             19
# 231     41                  user_gender_id_user_occupation_id             19
# 232    101        user_item_brand_id_click_time_gap_after_day             17
# 233    100       user_item_brand_id_click_time_gap_before_day             17
# 234    264                          user_item_id_future_15min             17
# 235    242                 item_property_topic_k_10_click_day             16
# 236    257           user_item_sales_level_bin_continue_click             16
# 237    189           user_id_item_sales_level_bin_history_CTR             15
# 238     49                             user_shop_id_click_day             15
# 239     89               user_shop_id_last_click_interval_day             15
# 240    182                                    hour_smooth_CTR             14
# 241     64               user_item_sales_level_bin_click_hour             14
# 242     60                      user_item_brand_id_click_hour             14
# 243    268         user_item_property_topic_k_10_future_15min             13
# 244     51                       user_item_brand_id_click_day             13
# 245    170                         context_page_id_smooth_CTR             12
# 246     97                  user_item_brand_id_click_rank_day             12
# 247     91              user_shop_id_click_time_gap_after_day             12
# 248    239                          category2_label_click_day             12
# 249     58                            user_shop_id_click_hour             12
# 250    180                                      hour_smooth_I             11
# 251    240                          category3_label_click_day             11
# 252    269             user_item_sales_level_bin_future_15min             10
# 253     21                                               hour             10
# 254    253                        user_shop_id_continue_click             10
# 255    271             user_item_price_level_bin_future_15min              9
# 256    165                           category3_label_smooth_I              9
# 257    154                                   user_id_smooth_C              9
# 258     10                                 user_occupation_id              8
# 259    263                          user_shop_id_future_15min              8
# 260    162                           category2_label_smooth_I              8
# 261      8                                     user_gender_id              8
# 262     59                            user_item_id_click_hour              7
# 263    168                           context_page_id_smooth_I              5
# 264    102       user_item_property_topic_k_10_click_rank_day              5
# 265    169                           context_page_id_smooth_C              3
# 266    177                      item_price_level_bin_smooth_I              3
# 267    178                      item_price_level_bin_smooth_C              2
# 268    266                    user_item_brand_id_future_15min              2
# 269    181                                      hour_smooth_C              1
# 270    179                    item_price_level_bin_smooth_CTR              0
# 271    265                     user_item_brand_id_future_2min              0

# %% [markdown]
# ## 输出临时文件，用于组合

# %%
test_data['predicted_score'] = bst.predict(test_data[features])

test_data[['instance_id', 'predicted_score']].to_csv(
    'day567-hour-2-depth-5-iter-1355-loss-163204.txt', index=False, sep=' ')
# Out:
# /home/user02/miniconda3/envs/gluon/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
