# %%
import os
import zipfile
import time
import pickle
import gc

import pandas as pd
import numpy as np
from tqdm import tqdm

from utils import load_pickle, dump_pickle, get_feature_value, feature_spearmanr, feature_target_spearmanr, addCrossFeature, calibration
from utils import raw_data_path, feature_data_path, cache_pkl_path, analyse

from sklearn.metrics import log_loss
import lightgbm as lgb

# %%
all_data_path = feature_data_path + 'all_data_all_features_new_0512.pkl'
all_data = load_pickle(all_data_path)

# %%
target = 'is_trade'

features = load_pickle('all_features_day_4567.pkl')
categorical_feature = load_pickle('categorical_feature.pkl')

len(features), len(categorical_feature)
# Out:
# (253, 1)

# %%
# data = all_data[(all_data.day == 7) & (all_data.is_trade >= 0)]
# data.loc[data.hour <= 1, hour_features] = np.NAN

# train_data = data[(data.hour < 11)]
# test_data = data[data.hour >= 11]


# data = all_data[(all_data.is_trade >= 0) & (all_data.day != 5) & (all_data.day != 6)]

data = all_data[(all_data.is_trade >= 0)]
all_data = None
gc.collect()

train_data = data[(data.hour < 10) | (data.day < 7)]
test_data_1 = data[(data.hour >= 10) & (data.day == 7)]
# test_data_2 = data[(data.hour == 11) & (data.day == 7)]

data = None
gc.collect()


lgb_train_data = lgb.Dataset(
    train_data[features], label=train_data[target], feature_name=features, categorical_feature=categorical_feature)
lgb_test_data_1 = lgb_train_data.create_valid(
    test_data_1[features], label=test_data_1[target])
# lgb_test_data_2 = lgb_train_data.create_valid(
#     test_data_2[features], label=test_data_2[target])

train_data.shape, test_data_1.shape
# Out:
# ((5099741, 573), (269737, 573))

# %% [markdown]
# ### 取7号上午数据进行训练和测试，以11点为分割

# %%
param = {'application': 'binary',
         'metric': 'binary_logloss',

         'learning_rate': 0.05,

         'max_depth': 5,
         'num_leaves': 20,

         'min_data_in_leaf': 200,
         'min_sum_hessian_in_leaf': 0.001,
         'min_gain_to_split': 0.1,

         'feature_fraction': 0.8,
         'bagging_fraction': 0.7,
         'bagging_freq': 1,

         'lambda_l2': 10,
         'max_bin': 63,

         'device': 'gpu',
         'gpu_use_dp': True,
         
#          'num_threads': 1,
         }


valid_sets = [lgb_train_data, lgb_test_data_1,]

bst = lgb.train(param, lgb_train_data, 
                valid_sets=valid_sets, 
                num_boost_round=4000, 
                early_stopping_rounds=300, 
                verbose_eval=20, 
                categorical_feature=categorical_feature
               )
# Out:
# Training until validation scores don't improve for 300 rounds.
# [20]	training's binary_logloss: 0.230852	valid_1's binary_logloss: 0.291315
# [40]	training's binary_logloss: 0.113643	valid_1's binary_logloss: 0.199055
# [60]	training's binary_logloss: 0.0782813	valid_1's binary_logloss: 0.17545
# [80]	training's binary_logloss: 0.0675685	valid_1's binary_logloss: 0.16931
# [100]	training's binary_logloss: 0.0643111	valid_1's binary_logloss: 0.167356
# [120]	training's binary_logloss: 0.0631356	valid_1's binary_logloss: 0.166227
# [140]	training's binary_logloss: 0.0625712	valid_1's binary_logloss: 0.16558
# [160]	training's binary_logloss: 0.0622344	valid_1's binary_logloss: 0.165076
# [180]	training's binary_logloss: 0.0619756	valid_1's binary_logloss: 0.164686
# [200]	training's binary_logloss: 0.0617979	valid_1's binary_logloss: 0.164396
# [220]	training's binary_logloss: 0.0616491	valid_1's binary_logloss: 0.16415
# [240]	training's binary_logloss: 0.0615266	valid_1's binary_logloss: 0.163977
# [260]	training's binary_logloss: 0.0614154	valid_1's binary_logloss: 0.163806
# [280]	training's binary_logloss: 0.0613269	valid_1's binary_logloss: 0.163676
# [300]	training's binary_logloss: 0.0612425	valid_1's binary_logloss: 0.163542
# [320]	training's binary_logloss: 0.0611624	valid_1's binary_logloss: 0.163453
# [340]	training's binary_logloss: 0.0610863	valid_1's binary_logloss: 0.163352
# [360]	training's binary_logloss: 0.0610199	valid_1's binary_logloss: 0.163277
# [380]	training's binary_logloss: 0.060962	valid_1's binary_logloss: 0.163215
# [400]	training's binary_logloss: 0.0609034	valid_1's binary_logloss: 0.163146
# [420]	training's binary_logloss: 0.0608506	valid_1's binary_logloss: 0.163094
# [440]	training's binary_logloss: 0.0607978	valid_1's binary_logloss: 0.163048
# [460]	training's binary_logloss: 0.0607485	valid_1's binary_logloss: 0.162993
# [480]	training's binary_logloss: 0.0606989	valid_1's binary_logloss: 0.162956
# [500]	training's binary_logloss: 0.0606529	valid_1's binary_logloss: 0.16291
# [520]	training's binary_logloss: 0.0606064	valid_1's binary_logloss: 0.162865
# [540]	training's binary_logloss: 0.060562	valid_1's binary_logloss: 0.162828
# [560]	training's binary_logloss: 0.0605176	valid_1's binary_logloss: 0.16279
# [580]	training's binary_logloss: 0.0604777	valid_1's binary_logloss: 0.162774
# [600]	training's binary_logloss: 0.0604355	valid_1's binary_logloss: 0.16274
# [620]	training's binary_logloss: 0.0603967	valid_1's binary_logloss: 0.162715
# [640]	training's binary_logloss: 0.0603575	valid_1's binary_logloss: 0.162691
# [660]	training's binary_logloss: 0.0603164	valid_1's binary_logloss: 0.162654
# [680]	training's binary_logloss: 0.0602768	valid_1's binary_logloss: 0.16263
# [700]	training's binary_logloss: 0.0602398	valid_1's binary_logloss: 0.162612
# [720]	training's binary_logloss: 0.0602021	valid_1's binary_logloss: 0.162593
# [740]	training's binary_logloss: 0.0601685	valid_1's binary_logloss: 0.16258
# [760]	training's binary_logloss: 0.0601332	valid_1's binary_logloss: 0.162561
# [780]	training's binary_logloss: 0.0600966	valid_1's binary_logloss: 0.162538
# [800]	training's binary_logloss: 0.0600604	valid_1's binary_logloss: 0.162528
# [820]	training's binary_logloss: 0.0600237	valid_1's binary_logloss: 0.162519
# [840]	training's binary_logloss: 0.0599901	valid_1's binary_logloss: 0.162513
# [860]	training's binary_logloss: 0.0599568	valid_1's binary_logloss: 0.162503
# [880]	training's binary_logloss: 0.0599216	valid_1's binary_logloss: 0.162485
# [900]	training's binary_logloss: 0.0598883	valid_1's binary_logloss: 0.162471
# [920]	training's binary_logloss: 0.0598553	valid_1's binary_logloss: 0.162468
# [940]	training's binary_logloss: 0.0598219	valid_1's binary_logloss: 0.16246
# [960]	training's binary_logloss: 0.0597855	valid_1's binary_logloss: 0.162451
# [980]	training's binary_logloss: 0.0597529	valid_1's binary_logloss: 0.162442
# [1000]	training's binary_logloss: 0.0597211	valid_1's binary_logloss: 0.162434
# [1020]	training's binary_logloss: 0.0596898	valid_1's binary_logloss: 0.162424
# [1040]	training's binary_logloss: 0.0596574	valid_1's binary_logloss: 0.162409
# [1060]	training's binary_logloss: 0.059625	valid_1's binary_logloss: 0.162405
# [1080]	training's binary_logloss: 0.0595933	valid_1's binary_logloss: 0.162395
# [1100]	training's binary_logloss: 0.0595618	valid_1's binary_logloss: 0.162379
# [1120]	training's binary_logloss: 0.0595323	valid_1's binary_logloss: 0.162381
# [1140]	training's binary_logloss: 0.0595015	valid_1's binary_logloss: 0.162373
# [1160]	training's binary_logloss: 0.0594709	valid_1's binary_logloss: 0.162371
# [1180]	training's binary_logloss: 0.0594395	valid_1's binary_logloss: 0.162373
# [1200]	training's binary_logloss: 0.0594089	valid_1's binary_logloss: 0.162364
# [1220]	training's binary_logloss: 0.0593775	valid_1's binary_logloss: 0.162363
# [1240]	training's binary_logloss: 0.0593496	valid_1's binary_logloss: 0.162359
# [1260]	training's binary_logloss: 0.0593168	valid_1's binary_logloss: 0.162346
# [1280]	training's binary_logloss: 0.0592867	valid_1's binary_logloss: 0.162339
# [1300]	training's binary_logloss: 0.0592574	valid_1's binary_logloss: 0.162334
# [1320]	training's binary_logloss: 0.0592273	valid_1's binary_logloss: 0.162334
# [1340]	training's binary_logloss: 0.0591982	valid_1's binary_logloss: 0.16233
# [1360]	training's binary_logloss: 0.0591688	valid_1's binary_logloss: 0.162327
# [1380]	training's binary_logloss: 0.0591391	valid_1's binary_logloss: 0.162325
# [1400]	training's binary_logloss: 0.0591096	valid_1's binary_logloss: 0.162327
# [1420]	training's binary_logloss: 0.05908	valid_1's binary_logloss: 0.162329
# [1440]	training's binary_logloss: 0.0590509	valid_1's binary_logloss: 0.162325
# [1460]	training's binary_logloss: 0.0590223	valid_1's binary_logloss: 0.162329
# [1480]	training's binary_logloss: 0.058993	valid_1's binary_logloss: 0.162323
# [1500]	training's binary_logloss: 0.058964	valid_1's binary_logloss: 0.162319
# [1520]	training's binary_logloss: 0.0589361	valid_1's binary_logloss: 0.162329
# [1540]	training's binary_logloss: 0.0589081	valid_1's binary_logloss: 0.162325
# [1560]	training's binary_logloss: 0.0588799	valid_1's binary_logloss: 0.162323
# [1580]	training's binary_logloss: 0.0588501	valid_1's binary_logloss: 0.162324
# [1600]	training's binary_logloss: 0.0588232	valid_1's binary_logloss: 0.162329
# [1620]	training's binary_logloss: 0.0587955	valid_1's binary_logloss: 0.162332
# [1640]	training's binary_logloss: 0.0587674	valid_1's binary_logloss: 0.162331
# [1660]	training's binary_logloss: 0.0587384	valid_1's binary_logloss: 0.162329
# [1680]	training's binary_logloss: 0.0587101	valid_1's binary_logloss: 0.162325
# [1700]	training's binary_logloss: 0.0586834	valid_1's binary_logloss: 0.162323
# [1720]	training's binary_logloss: 0.0586568	valid_1's binary_logloss: 0.162332
# [1740]	training's binary_logloss: 0.0586301	valid_1's binary_logloss: 0.162329
# [1760]	training's binary_logloss: 0.0586036	valid_1's binary_logloss: 0.162329
# [1780]	training's binary_logloss: 0.0585755	valid_1's binary_logloss: 0.162328
# Early stopping, best iteration is:
# [1497]	training's binary_logloss: 0.0589682	valid_1's binary_logloss: 0.162316

# %%
predict_train = bst.predict(train_data[features])
predict_test = bst.predict(test_data_1[features])

train_ctr = float(sum(predict_train)/float(len(predict_train)))
test_ctr = float(sum(predict_test)/float(len(predict_test)))
train_ctr, test_ctr
# Out:
# (0.015202567101391316, 0.04391718330513906)

# %% [markdown]
# ## 特征重要度

# %%
importance = pd.DataFrame(bst.feature_importance())
importance.columns = ['importance_20']
features = pd.DataFrame(features)
features.columns = ['features_20']
pd.set_option('max_rows',500)
merge = features.join(importance)
merge = merge.sort_values(by=['importance_20'], ascending=False).reset_index()
merge
# Out:
#      index                                        features_20  importance_20
# 0        4                                   item_sales_level           1319
# 1      126                                    hour_smooth_CTR           1208
# 2       53                          user_click_time_gap_after           1143
# 3        0                                            item_id            949
# 4       12                                            shop_id            942
# 5      134                  user_gender_id_shop_id_smooth_CTR            929
# 6      135                  user_gender_id_item_id_smooth_CTR            929
# 7       41                             user_id_click_day_mean            871
# 8      140              user_occupation_id_shop_id_smooth_CTR            831
# 9        2                                       item_city_id            803
# 10      17                                shop_score_delivery            803
# 11      18                             shop_score_description            786
# 12     141              user_occupation_id_item_id_smooth_CTR            765
# 13       5                               item_collected_level            734
# 14      16                                 shop_score_service            711
# 15     138                  user_age_level_item_id_smooth_CTR            707
# 16     159                         context_page_id_click_hour            707
# 17       1                                      item_brand_id            701
# 18     155                                 item_id_click_hour            685
# 19      14                          shop_review_positive_rate            684
# 20     161                item_property_topic_k_15_click_hour            681
# 21      10                                    user_star_level            669
# 22     136            user_gender_id_item_brand_id_smooth_CTR            649
# 23      59      user_category2_label_click_time_gap_after_day            649
# 24     144                 user_star_level_item_id_smooth_CTR            647
# 25      51                       user_click_interval_last_day            638
# 26      57       user_category2_label_last_click_interval_day            617
# 27     139            user_age_level_item_brand_id_smooth_CTR            609
# 28      45                             item_id_click_day_mean            609
# 29     142        user_occupation_id_item_brand_id_smooth_CTR            605
# 30     160                                 shop_id_click_hour            603
# 31     137                  user_age_level_shop_id_smooth_CTR            582
# 32     112          user_age_level_category2_label_smooth_CTR            576
# 33     157                         category2_label_click_hour            570
# 34     145           user_star_level_item_brand_id_smooth_CTR            567
# 35      44                             shop_id_click_day_mean            557
# 36      13                              shop_review_num_level            547
# 37     143                 user_star_level_shop_id_smooth_CTR            545
# 38     199                   user_age_level_shop_id_click_day            529
# 39      50                      user_click_interval_first_day            505
# 40     196                   user_gender_id_shop_id_click_day            497
# 41     200                   user_age_level_item_id_click_day            496
# 42     197                   user_gender_id_item_id_click_day            495
# 43     147                                  item_id_click_day            482
# 44     124          user_age_level_user_star_level_smooth_CTR            469
# 45      52                         user_click_time_gap_before            462
# 46     202               user_occupation_id_shop_id_click_day            458
# 47     203               user_occupation_id_item_id_click_day            457
# 48     111         user_age_level_item_price_level_smooth_CTR            446
# 49     158                         category3_label_click_hour            446
# 50     152                                  shop_id_click_day            444
# 51     146                                  user_id_click_day            442
# 52      88                     user_item_id_click_rank_global            438
# 53     125      user_occupation_id_user_star_level_smooth_CTR            434
# 54      64      user_category3_label_click_time_gap_after_day            425
# 55     187         user_star_level_item_price_level_click_day            425
# 56     107                              category_predict_rank            421
# 57     118         user_star_level_category2_label_smooth_CTR            421
# 58     120           user_gender_id_user_age_level_smooth_CTR            420
# 59     156                           item_brand_id_click_hour            420
# 60     188          user_star_level_category2_label_click_day            413
# 61     151                          context_page_id_click_day            408
# 62      15                                    shop_star_level            403
# 63     122          user_gender_id_user_star_level_smooth_CTR            402
# 64     182           user_age_level_category2_label_click_day            389
# 65     115      user_occupation_id_category2_label_smooth_CTR            385
# 66     109          user_gender_id_category2_label_smooth_CTR            385
# 67     204         user_occupation_id_item_brand_id_click_day            384
# 68     195       user_occupation_id_user_star_level_click_day            384
# 69     217                     shop_score_description_bin_day            381
# 70     185       user_occupation_id_category2_label_click_day            381
# 71     153                 item_property_topic_k_15_click_day            377
# 72     192           user_gender_id_user_star_level_click_day            375
# 73     130                  user_id_category3_label_history_I            375
# 74     198             user_gender_id_item_brand_id_click_day            372
# 75     117        user_star_level_item_price_level_smooth_CTR            367
# 76      63     user_category3_label_click_time_gap_before_day            362
# 77     179           user_gender_id_category2_label_click_day            359
# 78      54                             user_click_rank_global            355
# 79     201             user_age_level_item_brand_id_click_day            354
# 80      62       user_category3_label_last_click_interval_day            352
# 81     181          user_age_level_item_price_level_click_day            348
# 82      20                                    category2_label            346
# 83      61      user_category3_label_first_click_interval_day            342
# 84      19                                                day            335
# 85     215                         shop_score_service_bin_day            334
# 86     114     user_occupation_id_item_price_level_smooth_CTR            334
# 87      46                       item_brand_id_click_day_mean            333
# 88     194           user_age_level_user_star_level_click_day            333
# 89     216                        shop_score_delivery_bin_day            331
# 90     184      user_occupation_id_item_price_level_click_day            321
# 91     133             user_id_item_price_level_bin_history_I            321
# 92     105                             item_property_topic_14            319
# 93     149                          category2_label_click_day            319
# 94     119         user_star_level_category3_label_smooth_CTR            319
# 95      56      user_category2_label_first_click_interval_day            318
# 96     233    user_occupation_id_item_property_topic_k_15_day            318
# 97      23                     user_category2_label_click_day            314
# 98       6                                      item_pv_level            312
# 99      85             user_category2_label_click_rank_global            311
# 100     98                              item_property_topic_7            309
# 101    123       user_age_level_user_occupation_id_smooth_CTR            306
# 102     58     user_category2_label_click_time_gap_before_day            303
# 103    106                                       property_sim            297
# 104    213                  shop_review_positive_rate_bin_day            296
# 105     94                              item_property_topic_3            295
# 106    209                           item_sales_level_bin_day            291
# 107    121       user_gender_id_user_occupation_id_smooth_CTR            289
# 108    113          user_age_level_category3_label_smooth_CTR            289
# 109    229        user_age_level_item_property_topic_k_15_day            287
# 110    218                                category2_label_day            286
# 111    190            user_gender_id_user_age_level_click_day            284
# 112    227                 user_age_level_category2_label_day            282
# 113     83  user_item_property_topic_k_15_click_time_gap_b...            282
# 114     81  user_item_property_topic_k_15_first_click_inte...            279
# 115    221                                context_page_id_day            276
# 116    178          user_gender_id_item_price_level_click_day            271
# 117    212                      shop_review_num_level_bin_day            271
# 118    148                            item_brand_id_click_day            269
# 119    210                       item_collected_level_bin_day            269
# 120      8                                     user_age_level            268
# 121    154                                 user_id_click_hour            267
# 122    220                       item_property_topic_k_15_day            267
# 123     28                     user_context_page_id_click_day            264
# 124    183           user_age_level_category3_label_click_day            264
# 125    189          user_star_level_category3_label_click_day            263
# 126    108         user_gender_id_item_price_level_smooth_CTR            256
# 127     42                     category2_label_click_day_mean            256
# 128    193        user_age_level_user_occupation_id_click_day            251
# 129    211                              item_pv_level_bin_day            248
# 130    225        user_gender_id_item_property_topic_k_15_day            245
# 131    231             user_occupation_id_category2_label_day            241
# 132    103                             item_property_topic_12            241
# 133    191        user_gender_id_user_occupation_id_click_day            241
# 134     95                              item_property_topic_4            240
# 135    226            user_age_level_item_price_level_bin_day            240
# 136     74              user_item_id_click_time_gap_after_day            238
# 137    180           user_gender_id_category3_label_click_day            237
# 138    100                              item_property_topic_9            236
# 139     22                           item_property_topic_k_15            234
# 140    102                             item_property_topic_11            233
# 141    165                user_category2_label_continue_click            231
# 142     82  user_item_property_topic_k_15_last_click_inter...            230
# 143    104                             item_property_topic_13            230
# 144    129                  user_id_category2_label_history_I            224
# 145     24                     user_category3_label_click_day            222
# 146    223                 user_gender_id_category2_label_day            222
# 147     29                user_item_price_level_bin_click_day            222
# 148    116      user_occupation_id_category3_label_smooth_CTR            222
# 149    110          user_gender_id_category3_label_smooth_CTR            219
# 150     96                              item_property_topic_5            217
# 151     32                    user_category2_label_click_hour            213
# 152     43                     category3_label_click_day_mean            205
# 153     97                              item_property_topic_6            205
# 154     84  user_item_property_topic_k_15_click_time_gap_a...            204
# 155     91                              item_property_topic_0            201
# 156    166                user_category3_label_continue_click            200
# 157    170                  user_category2_label_future_15min            199
# 158    228                 user_age_level_category3_label_day            199
# 159    214                            shop_star_level_bin_day            198
# 160     92                              item_property_topic_1            192
# 161    230        user_occupation_id_item_price_level_bin_day            190
# 162    186       user_occupation_id_category3_label_click_day            189
# 163    236              user_age_level_user_occupation_id_day            185
# 164     71              user_item_id_first_click_interval_day            185
# 165     47                     context_page_id_click_day_mean            182
# 166    171                  user_category3_label_future_15min            179
# 167     73             user_item_id_click_time_gap_before_day            178
# 168     33                    user_category3_label_click_hour            177
# 169     31            user_item_property_topic_k_15_click_day            176
# 170     37                    user_context_page_id_click_hour            174
# 171     90    user_item_property_topic_k_15_click_rank_global            172
# 172     11                                    context_page_id            172
# 173     21                                    category3_label            167
# 174    132             user_id_item_sales_level_bin_history_I            166
# 175     93                              item_property_topic_2            165
# 176     99                              item_property_topic_8            165
# 177     38               user_item_price_level_bin_click_hour            161
# 178    169           user_item_price_level_bin_continue_click            161
# 179    222            user_gender_id_item_price_level_bin_day            161
# 180    101                             item_property_topic_10            158
# 181    224                 user_gender_id_category3_label_day            154
# 182    232             user_occupation_id_category3_label_day            153
# 183     49                           user_click_true_rank_day            153
# 184     79        user_item_brand_id_click_time_gap_after_day            147
# 185     66              user_shop_id_first_click_interval_day            146
# 186     30                user_item_sales_level_bin_click_day            141
# 187    167       user_item_property_topic_k_15_continue_click            137
# 188    127                          user_id_item_id_history_I            135
# 189    162                        user_item_id_continue_click            133
# 190     76        user_item_brand_id_first_click_interval_day            132
# 191      3                                   item_price_level            132
# 192    150                          category3_label_click_day            131
# 193    234                  user_gender_id_user_age_level_day            129
# 194     78       user_item_brand_id_click_time_gap_before_day            128
# 195     86             user_category3_label_click_rank_global            127
# 196     40           user_item_property_topic_k_15_click_hour            125
# 197     77         user_item_brand_id_last_click_interval_day            105
# 198     68             user_shop_id_click_time_gap_before_day            104
# 199     55                user_category2_label_click_rank_day            104
# 200     27                       user_item_brand_id_click_day            102
# 201     39               user_item_sales_level_bin_click_hour            100
# 202    208                           item_price_level_bin_day             96
# 203     72               user_item_id_last_click_interval_day             94
# 204    235              user_gender_id_user_occupation_id_day             94
# 205    168           user_item_sales_level_bin_continue_click             93
# 206     48                                user_click_rank_day             89
# 207    131                          user_id_shop_id_history_I             89
# 208    219                                category3_label_day             89
# 209     36                      user_item_brand_id_click_hour             87
# 210     26                             user_item_id_click_day             85
# 211    177             user_item_price_level_bin_future_15min             85
# 212     89               user_item_brand_id_click_rank_global             84
# 213     60                user_category3_label_click_rank_day             81
# 214    128                    user_id_item_brand_id_history_I             81
# 215     87                     user_shop_id_click_rank_global             76
# 216    175         user_item_property_topic_k_15_future_15min             75
# 217    163                  user_item_brand_id_continue_click             71
# 218     80       user_item_property_topic_k_15_click_rank_day             70
# 219     69              user_shop_id_click_time_gap_after_day             70
# 220    176             user_item_sales_level_bin_future_15min             68
# 221     34                            user_shop_id_click_hour             66
# 222      9                                 user_occupation_id             60
# 223     67               user_shop_id_last_click_interval_day             54
# 224    206                                 user_age_level_day             54
# 225    164                        user_shop_id_continue_click             49
# 226    207                             user_occupation_id_day             49
# 227     70                        user_item_id_click_rank_day             48
# 228     25                             user_shop_id_click_day             48
# 229    172                          user_shop_id_future_15min             45
# 230      7                                     user_gender_id             44
# 231    173                          user_item_id_future_15min             40
# 232     35                            user_item_id_click_hour             36
# 233     75                  user_item_brand_id_click_rank_day             29
# 234    174                    user_item_brand_id_future_15min             21
# 235     65                        user_shop_id_click_rank_day             19
# 236    205                                 user_gender_id_day             15

# %% [markdown]
# ## 输出临时文件，用于组合

# %%
test_data_1['predicted_score'] = bst.predict(test_data_1[features])

test_data_1[['instance_id', 'predicted_score']].to_csv(
    'yym-0514-hour-1-step-003-loss-160395.txt', index=False, sep=' ')

# %%
test_data_1['predicted_score'] = bst.predict(test_data_1[features])

test_data_1[['instance_id', 'predicted_score']].to_csv(
    'yym-0514-hour-2-step-005-loss-162316.txt', index=False, sep=' ')

# %%
[1497]	training's binary_logloss: 0.0589682	valid_1's binary_logloss: 0.162316   1780
