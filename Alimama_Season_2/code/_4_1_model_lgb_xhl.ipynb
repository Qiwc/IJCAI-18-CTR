# %%
import os
import zipfile
import time
import pickle
import gc

import pandas as pd
import numpy as np
from tqdm import tqdm

from utils import load_pickle, dump_pickle, get_feature_value, feature_spearmanr, feature_target_spearmanr, addCrossFeature, calibration
from utils import raw_data_path, feature_data_path, cache_pkl_path, analyse

# %%
all_data_path = feature_data_path + 'all_data_all_features.pkl'
all_data = load_pickle(all_data_path)

target = 'is_trade'

features = load_pickle('all_features.pkl')
categorical_feature = load_pickle('categorical_feature.pkl')

# 只使用原始特征
# features = load_pickle('original_features.pkl')
# categorical_feature = ['user_gender_id', 'user_occupation_id']

len(features), len(categorical_feature)
# Out:
# (292, 15)

# %% [markdown]
# ### 取7号上午数据进行训练和测试，以11点为分割

# %%
data = all_data[(all_data.day == 7) & (all_data.is_trade != -1)]

train_data = data[(data.hour < 11)]
test_data = data[data.hour >= 11]

print(train_data.shape)
print(test_data.shape)
# Out:
# (950233, 312)
# (126942, 312)

# %%
from sklearn.metrics import log_loss
import lightgbm as lgb

lgb_train_data = lgb.Dataset(
    train_data[features], label=train_data[target], feature_name=features, categorical_feature=categorical_feature)
lgb_test_data = lgb_train_data.create_valid(
    test_data[features], label=test_data[target])

param = {'application': 'binary',
         'metric': 'binary_logloss',

         'learning_rate': 0.005,
         
         'boosting':'rf',

         'max_depth': 100,
         'num_leaves': 18,

         'min_data_in_leaf': 500,
         'min_sum_hessian_in_leaf': 0.01,
         'min_gain_to_split': 0.1,

         'feature_fraction': 0.9,
         'bagging_fraction': 0.8,
         'bagging_freq': 1,

         'lambda_l2': 1.0,
         'max_bin': 63,

#          'device': 'gpu',
#          'gpu_use_dp': False,
         }


valid_sets = [lgb_train_data, lgb_test_data]

bst = lgb.train(param, lgb_train_data, valid_sets=valid_sets, 
                num_boost_round=2000, early_stopping_rounds=100, verbose_eval=20, 
                categorical_feature=categorical_feature
               )

loss_train = log_loss(train_data[target], bst.predict(train_data[features]))
loss_test = log_loss(test_data[target], bst.predict(test_data[features]))

loss_train, loss_test
# Out:
# /home/user02/miniconda3/envs/gluon/lib/python3.6/site-packages/lightgbm/basic.py:1038: UserWarning: categorical_feature in Dataset is overrided. New categorical_feature is ['category_predict_rank', 'item_property_topic', 'user_category2_label_click_rank_day', 'user_category2_label_pre_click', 'user_category3_label_click_rank_day', 'user_category3_label_pre_click', 'user_click_rank_day', 'user_gender_id', 'user_item_brand_id_click_rank_day', 'user_item_brand_id_pre_click', 'user_item_id_click_rank_day', 'user_item_id_pre_click', 'user_occupation_id', 'user_shop_id_click_rank_day', 'user_shop_id_pre_click']
#   warnings.warn('categorical_feature in Dataset is overrided. New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/user02/miniconda3/envs/gluon/lib/python3.6/site-packages/lightgbm/basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# Training until validation scores don't improve for 100 rounds.
# [20]	training's binary_logloss: 0.232141	valid_1's binary_logloss: 0.226506
# [40]	training's binary_logloss: 0.232135	valid_1's binary_logloss: 0.226499
# [60]	training's binary_logloss: 0.232134	valid_1's binary_logloss: 0.226501
# [80]	training's binary_logloss: 0.232141	valid_1's binary_logloss: 0.226506
# [100]	training's binary_logloss: 0.232141	valid_1's binary_logloss: 0.226506
# [120]	training's binary_logloss: 0.232142	valid_1's binary_logloss: 0.226505
# [140]	training's binary_logloss: 0.232141	valid_1's binary_logloss: 0.226503
# Early stopping, best iteration is:
# [44]	training's binary_logloss: 0.232133	valid_1's binary_logloss: 0.226497
# (0.23213265947035749, 0.22649706671461134)

# %% [markdown]
# ## 输出临时文件，用于组合

# %%
test_data['predicted_score'] = bst.predict(test_data[features])

test_data[['instance_id', 'predicted_score']].to_csv(
    'hour-1-depth-5-iter-1061-loss-16138.txt', index=False, sep=' ')
# Out:
# /home/user02/miniconda3/envs/gluon/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## 特征重要度

# %%
importance = pd.DataFrame(bst.feature_importance())
importance.columns = ['importance_20']
features = pd.DataFrame(features)
features.columns = ['features_20']
pd.set_option('max_rows',500)
merge = features.join(importance)
merge = merge.sort_values(by=['importance_20'], ascending=False).reset_index()
merge
# Out:
#      index                                        features_20  importance_20
# 0      138                                item_property_topic           1665
# 1        4                                   item_sales_level            570
# 2       51                          user_click_time_gap_after            323
# 3       61       user_category2_label_last_click_interval_day            263
# 4       11                                    user_star_level            244
# 5      146                                 item_id_smooth_CTR            232
# 6       15                                            shop_id            189
# 7      225          user_age_level_category2_label_smooth_CTR            180
# 8      276                                 item_id_click_hour            178
# 9        0                                            item_id            176
# 10       2                                       item_city_id            172
# 11      21                             shop_score_description            169
# 12      20                                shop_score_delivery            167
# 13       5                               item_collected_level            164
# 14     141                                   user_id_smooth_I            161
# 15      49                       user_click_interval_last_day            157
# 16      13                                  context_timestamp            155
# 17      16                              shop_review_num_level            147
# 18      39                             user_id_click_day_mean            144
# 19       1                                      item_brand_id            142
# 20      12                                         context_id            135
# 21      79               user_item_id_last_click_interval_day            131
# 22     253                  item_id_user_gender_id_click_rate            129
# 23      24                                             minute            126
# 24     280                         context_page_id_click_hour            124
# 25     281                                 shop_id_click_hour            122
# 26     161                                 shop_id_smooth_CTR            121
# 27     149                           item_brand_id_smooth_CTR            121
# 28      19                                 shop_score_service            121
# 29     217                    user_age_level_item_id_smooth_I            120
# 30       7                                            user_id            119
# 31      17                          shop_review_positive_rate            117
# 32     139                              category_predict_rank            117
# 33      48                      user_click_interval_first_day            113
# 34      31                     user_category2_label_click_day            112
# 35     269                                  item_id_click_day            110
# 36     251                  shop_id_user_age_level_click_rate            110
# 37     254                  item_id_user_age_level_click_rate            108
# 38     231                     user_age_level_hour_smooth_CTR            107
# 39     199                    user_gender_id_item_id_smooth_I            105
# 40     256            item_brand_id_user_gender_id_click_rate            105
# 41     278                         category2_label_click_hour            105
# 42     222            user_age_level_item_brand_id_smooth_CTR            102
# 43     201                  user_gender_id_item_id_smooth_CTR            102
# 44      18                                    shop_star_level            100
# 45     250                  shop_id_user_gender_id_click_rate             99
# 46      54                   user_click_interval_first_global             99
# 47     235                user_occupation_id_item_id_smooth_I             95
# 48     267                 hour_user_occupation_id_click_rate             95
# 49      56                  user_click_time_gap_before_global             92
# 50      14                                    context_page_id             91
# 51     255              item_id_user_occupation_id_click_rate             90
# 52     165                                      item_id_day_I             90
# 53       9                                     user_age_level             90
# 54      42                             shop_id_click_day_mean             89
# 55      63      user_category2_label_click_time_gap_after_day             88
# 56     219                  user_age_level_item_id_smooth_CTR             88
# 57     232                user_occupation_id_shop_id_smooth_I             88
# 58     214                    user_age_level_shop_id_smooth_I             87
# 59      67       user_category3_label_last_click_interval_day             87
# 60     258        item_brand_id_user_occupation_id_click_rate             87
# 61     257            item_brand_id_user_age_level_click_rate             87
# 62     140                                       property_sim             86
# 63     224            user_age_level_category2_label_smooth_C             85
# 64     106                     user_item_id_click_rank_global             84
# 65     252              shop_id_user_occupation_id_click_rate             84
# 66      25                                    category2_label             84
# 67      29                     user_context_page_id_click_day             84
# 68     182                                        shop_id_CTR             83
# 69     196                    user_gender_id_shop_id_smooth_I             83
# 70      69      user_category3_label_click_time_gap_after_day             82
# 71     151                           category2_label_smooth_C             81
# 72     197                    user_gender_id_shop_id_smooth_C             81
# 73      40                             item_id_click_day_mean             80
# 74       3                                   item_price_level             80
# 75     274                                  shop_id_click_day             79
# 76     170                                  item_brand_id_CTR             79
# 77     167                                        item_id_CTR             78
# 78     268                                  user_id_click_day             77
# 79     223            user_age_level_category2_label_smooth_I             76
# 80     237              user_occupation_id_item_id_smooth_CTR             75
# 81       6                                      item_pv_level             75
# 82     234              user_occupation_id_shop_id_smooth_CTR             74
# 83     180                                      shop_id_day_I             73
# 84     216                  user_age_level_shop_id_smooth_CTR             73
# 85     143                                 user_id_smooth_CTR             72
# 86     228          user_age_level_category3_label_smooth_CTR             72
# 87      76                        user_item_id_click_rank_day             72
# 88     277                           item_brand_id_click_hour             71
# 89     144                                   item_id_smooth_I             70
# 90      32                     user_category3_label_click_day             69
# 91      50                         user_click_time_gap_before             69
# 92     241        user_occupation_id_category2_label_smooth_I             69
# 93     266                     hour_user_age_level_click_rate             67
# 94     204            user_gender_id_item_brand_id_smooth_CTR             66
# 95     279                         category3_label_click_hour             65
# 96     202              user_gender_id_item_brand_id_smooth_I             64
# 97     259          category2_label_user_gender_id_click_rate             64
# 98     275                                 user_id_click_hour             64
# 99     215                    user_age_level_shop_id_smooth_C             63
# 100    198                  user_gender_id_shop_id_smooth_CTR             62
# 101    249                 user_occupation_id_hour_smooth_CTR             61
# 102    220              user_age_level_item_brand_id_smooth_I             61
# 103    160                                   shop_id_smooth_C             61
# 104    240        user_occupation_id_item_brand_id_smooth_CTR             61
# 105    265                     hour_user_gender_id_click_rate             60
# 106    260          category2_label_user_age_level_click_rate             58
# 107    188                          user_id_item_id_history_I             56
# 108    213                     user_gender_id_hour_smooth_CTR             55
# 109     96   user_category3_label_first_click_interval_global             55
# 110     92  user_category2_label_click_time_gap_before_global             55
# 111    205            user_gender_id_category2_label_smooth_I             53
# 112    145                                   item_id_smooth_C             52
# 113    261      category2_label_user_occupation_id_click_rate             52
# 114    233                user_occupation_id_shop_id_smooth_C             52
# 115    211                       user_gender_id_hour_smooth_I             51
# 116    226            user_age_level_category3_label_smooth_I             51
# 117    243      user_occupation_id_category2_label_smooth_CTR             51
# 118    247                   user_occupation_id_hour_smooth_I             51
# 119    159                                   shop_id_smooth_I             50
# 120    218                    user_age_level_item_id_smooth_C             50
# 121    110          user_item_id_click_time_gap_before_global             50
# 122     57                   user_click_time_gap_after_global             50
# 123     90   user_category2_label_first_click_interval_global             50
# 124    270                            item_brand_id_click_day             48
# 125    207          user_gender_id_category2_label_smooth_CTR             48
# 126    179                                context_page_id_CTR             48
# 127    238          user_occupation_id_item_brand_id_smooth_I             48
# 128     98  user_category3_label_click_time_gap_before_global             46
# 129    229                       user_age_level_hour_smooth_I             45
# 130    230                       user_age_level_hour_smooth_C             45
# 131    246      user_occupation_id_category3_label_smooth_CTR             45
# 132    203              user_gender_id_item_brand_id_smooth_C             45
# 133     46                                user_click_rank_day             44
# 134    242        user_occupation_id_category2_label_smooth_C             43
# 135    148                             item_brand_id_smooth_C             43
# 136    192                  user_id_category3_label_history_I             43
# 137     81              user_item_id_click_time_gap_after_day             41
# 138     53                        user_click_true_rank_global             41
# 139     37                    user_category2_label_click_hour             41
# 140    206            user_gender_id_category2_label_smooth_C             41
# 141    108           user_item_id_first_click_interval_global             40
# 142    282                             user_item_id_pre_click             40
# 143    236                user_occupation_id_item_id_smooth_C             40
# 144    263          category3_label_user_age_level_click_rate             40
# 145    262          category3_label_user_gender_id_click_rate             39
# 146     26                                    category3_label             39
# 147    210          user_gender_id_category3_label_smooth_CTR             39
# 148     87        user_item_brand_id_click_time_gap_after_day             38
# 149     44                     category2_label_click_day_mean             38
# 150    221              user_age_level_item_brand_id_smooth_C             37
# 151    168                                item_brand_id_day_I             36
# 152     68     user_category3_label_click_time_gap_before_day             36
# 153    147                             item_brand_id_smooth_I             36
# 154    154                           category3_label_smooth_C             35
# 155     66      user_category3_label_first_click_interval_day             34
# 156    209            user_gender_id_category3_label_smooth_C             34
# 157    200                    user_gender_id_item_id_smooth_C             33
# 158    264      category3_label_user_occupation_id_click_rate             33
# 159    128                             item_property_topic_10             33
# 160     35                    user_context_page_id_click_hour             33
# 161     38                    user_category3_label_click_hour             33
# 162     62     user_category2_label_click_time_gap_before_day             32
# 163    227            user_age_level_category3_label_smooth_C             32
# 164     60      user_category2_label_first_click_interval_day             31
# 165    162                                      user_id_day_I             31
# 166    107                user_item_id_click_true_rank_global             31
# 167     80             user_item_id_click_time_gap_before_day             31
# 168    114     user_item_brand_id_first_click_interval_global             31
# 169    137                             item_property_topic_19             31
# 170    129                             item_property_topic_11             31
# 171    208            user_gender_id_category3_label_smooth_I             30
# 172    181                                      shop_id_day_C             30
# 173    102           user_shop_id_first_click_interval_global             30
# 174    153                           category3_label_smooth_I             30
# 175    169                                item_brand_id_day_C             29
# 176    136                             item_property_topic_18             29
# 177    244        user_occupation_id_category3_label_smooth_I             29
# 178     88             user_category2_label_click_rank_global             28
# 179    123                              item_property_topic_5             28
# 180    116    user_item_brand_id_click_time_gap_before_global             28
# 181    245        user_occupation_id_category3_label_smooth_C             27
# 182     89        user_category2_label_click_true_rank_global             27
# 183    189                    user_id_item_brand_id_history_I             26
# 184     73               user_shop_id_last_click_interval_day             26
# 185     85         user_item_brand_id_last_click_interval_day             26
# 186     95        user_category3_label_click_true_rank_global             26
# 187    193                user_id_category3_label_history_CTR             26
# 188    239          user_occupation_id_item_brand_id_smooth_C             25
# 189    190                  user_id_category2_label_history_I             25
# 190     58                user_category2_label_click_rank_day             25
# 191     41                       item_brand_id_click_day_mean             25
# 192    158                         context_page_id_smooth_CTR             24
# 193    122                              item_property_topic_4             24
# 194    291                user_category3_label_continue_click             23
# 195     52                             user_click_rank_global             23
# 196     47                           user_click_true_rank_day             23
# 197     23                                               hour             23
# 198    120                              item_property_topic_2             23
# 199    175                              category3_label_day_C             23
# 200    121                              item_property_topic_3             23
# 201     34                      user_item_brand_id_click_hour             23
# 202    127                              item_property_topic_9             22
# 203    155                         category3_label_smooth_CTR             22
# 204    104          user_shop_id_click_time_gap_before_global             21
# 205    135                             item_property_topic_17             21
# 206     72              user_shop_id_first_click_interval_day             21
# 207    124                              item_property_topic_6             21
# 208    126                              item_property_topic_8             20
# 209     82                  user_item_brand_id_click_rank_day             19
# 210     70                        user_shop_id_click_rank_day             18
# 211    194                          user_id_shop_id_history_I             18
# 212     30                             user_shop_id_click_day             18
# 213     84        user_item_brand_id_first_click_interval_day             18
# 214    248                   user_occupation_id_hour_smooth_C             18
# 215     78              user_item_id_first_click_interval_day             17
# 216    133                             item_property_topic_15             17
# 217    173                                category2_label_CTR             17
# 218     27                             user_item_id_click_day             17
# 219     64                user_category3_label_click_rank_day             17
# 220    118                              item_property_topic_0             17
# 221    289                user_category2_label_continue_click             17
# 222     94             user_category3_label_click_rank_global             16
# 223     75              user_shop_id_click_time_gap_after_day             16
# 224     91    user_category2_label_last_click_interval_global             16
# 225    212                       user_gender_id_hour_smooth_C             16
# 226    176                                category3_label_CTR             16
# 227    185                      user_id_category2_label_day_I             16
# 228     86       user_item_brand_id_click_time_gap_before_day             16
# 229    132                             item_property_topic_14             15
# 230    130                             item_property_topic_12             15
# 231     28                       user_item_brand_id_click_day             15
# 232    131                             item_property_topic_13             14
# 233     65           user_category3_label_click_true_rank_day             14
# 234    112               user_item_brand_id_click_rank_global             13
# 235     74             user_shop_id_click_time_gap_before_day             13
# 236     55                    user_click_interval_last_global             13
# 237    272                          category3_label_click_day             13
# 238    271                          category2_label_click_day             12
# 239    166                                      item_id_day_C             12
# 240    172                              category2_label_day_C             12
# 241      8                                     user_gender_id             12
# 242    284                       user_item_brand_id_pre_click             12
# 243    186                      user_id_category3_label_day_I             12
# 244    125                              item_property_topic_7             11
# 245    152                         category2_label_smooth_CTR             11
# 246     33                            user_item_id_click_hour             11
# 247    101                user_shop_id_click_true_rank_global             11
# 248    288                     user_category2_label_pre_click             10
# 249    195                        user_id_shop_id_history_CTR             10
# 250     10                                 user_occupation_id             10
# 251     43                     context_page_id_click_day_mean              9
# 252    134                             item_property_topic_16              9
# 253    184                        user_id_item_brand_id_day_I              9
# 254     36                            user_shop_id_click_hour              9
# 255     77                   user_item_id_click_true_rank_day              8
# 256    119                              item_property_topic_1              8
# 257     93   user_category2_label_click_time_gap_after_global              8
# 258    191                user_id_category2_label_history_CTR              8
# 259    100                     user_shop_id_click_rank_global              7
# 260    290                     user_category3_label_pre_click              7
# 261     59           user_category2_label_click_true_rank_day              7
# 262     45                     category2_label_click_day_mean              7
# 263    187                              user_id_shop_id_day_I              6
# 264    286                             user_shop_id_pre_click              6
# 265    113          user_item_brand_id_click_true_rank_global              6
# 266    174                              category3_label_day_I              6
# 267     99   user_category3_label_click_time_gap_after_global              6
# 268    164                                        user_id_CTR              6
# 269    285                  user_item_brand_id_continue_click              6
# 270    171                              category2_label_day_I              5
# 271    103            user_shop_id_last_click_interval_global              5
# 272     97    user_category3_label_last_click_interval_global              5
# 273     83             user_item_brand_id_click_true_rank_day              5
# 274    142                                   user_id_smooth_C              4
# 275    105           user_shop_id_click_time_gap_after_global              4
# 276    109            user_item_id_last_click_interval_global              4
# 277    283                        user_item_id_continue_click              4
# 278    150                           category2_label_smooth_I              3
# 279    117     user_item_brand_id_click_time_gap_after_global              3
# 280    111           user_item_id_click_time_gap_after_global              3
# 281    157                           context_page_id_smooth_C              2
# 282     71                   user_shop_id_click_true_rank_day              2
# 283    287                        user_shop_id_continue_click              2
# 284    183                              user_id_item_id_day_I              2
# 285    178                              context_page_id_day_C              1
# 286    115      user_item_brand_id_last_click_interval_global              0
# 287    273                          context_page_id_click_day              0
# 288     22                                                day              0
# 289    177                              context_page_id_day_I              0
# 290    163                                      user_id_day_C              0
# 291    156                           context_page_id_smooth_I              0

# %% [markdown]
# ### 取6号和7号上午数据进行训练和测试，以7号11点为分割

# %%
data = all_data[all_data.is_trade != -1]

train_data = data[(data.day == 6) | ((data.hour < 11) & (data.day == 7))]
test_data = data[(data.hour >= 11) & (data.day == 7)]

print(train_data.shape)
print(test_data.shape)
# Out:
# (2884676, 169)
# (126942, 169)
