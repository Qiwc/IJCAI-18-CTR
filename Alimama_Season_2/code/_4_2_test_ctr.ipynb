# %%
import os
import zipfile
import time
import pickle
import gc

import pandas as pd
import numpy as np
from tqdm import tqdm

from utils import load_pickle, dump_pickle, get_feature_value, feature_spearmanr, feature_target_spearmanr, addCrossFeature, calibration
from utils import raw_data_path, feature_data_path, cache_pkl_path, analyse

# %%
all_data_path = feature_data_path + 'all_data_all_features_new_0512.pkl'
data = load_pickle(all_data_path)

# %%
target = 'is_trade'

features = load_pickle('all_features_day_4567.pkl')
categorical_feature = load_pickle('categorical_feature.pkl')

len(features), len(categorical_feature)
# Out:
# (253, 1)

# %%
# train_data = data[(data.is_trade != -1) & ((data.hour > 1) | ((data.hour == 1)&(data.minute >= 30)))]
# train_data = data[(data.is_trade >= 0) & (data.hour >= 1)]
# train_data.loc[train_data.hour <= 1, hour_features] = np.NAN


# train_data = data[(data.is_trade >= 0) & (data.day != 5) & (data.day != 6)]
train_data = data[(data.is_trade >= 0)]
test_data = data[data.is_trade == -2]

data = None
gc.collect()

print(train_data.shape)
print(test_data.shape)
# Out:
# (5369478, 573)
# (1209768, 573)

# %%
from sklearn.metrics import log_loss
import lightgbm as lgb

lgb_train_data = lgb.Dataset(
    train_data[features], label=train_data[target], feature_name=features,  categorical_feature=categorical_feature)

gc.collect()

param = {'application': 'binary',
         'metric': 'binary_logloss',

         'learning_rate': 0.1,

         'max_depth': 5,
         'num_leaves': 20,

         'min_data_in_leaf': 200,
         'min_sum_hessian_in_leaf': 0.01,
         'min_gain_to_split': 0.0,

         'feature_fraction': 0.8,
         'bagging_fraction': 0.7,
         'bagging_freq': 1,

         'lambda_l2': 10,
         'max_bin': 63,

         'device': 'gpu',
         'gpu_use_dp': False,
         
#          'num_threads': 16,
         }

# param = {'application': 'binary',
#          'metric': 'binary_logloss',

#          'learning_rate': 0.03,

#          'max_depth': 5,
#          'num_leaves': 20,

#          'min_data_in_leaf': 100,
#          'min_sum_hessian_in_leaf': 0.001,
#          'min_gain_to_split': 0.1,

#          'feature_fraction': 0.8,
#          'bagging_fraction': 0.7,
#          'bagging_freq': 1,

#          'lambda_l2': 10,
#          'max_bin': 63,

#          'device': 'gpu',
#          'gpu_use_dp': True,
         
# #          'num_threads': 1,
#          }

valid_sets = [lgb_train_data,]

bst = lgb.train(param, lgb_train_data, valid_sets=valid_sets, 
                categorical_feature=categorical_feature,
                num_boost_round=500, 
                verbose_eval=50,)


# predict_train = bst.predict(train_data[features])
predict_test = bst.predict(test_data[features])

# train_ctr = float(sum(predict_train)/float(len(predict_train)))
test_ctr = float(sum(predict_test)/float(len(predict_test)))

# train_ctr, 
test_ctr
# Out:
# [50]	training's binary_logloss: 0.069434
# [100]	training's binary_logloss: 0.0669751
# [150]	training's binary_logloss: 0.0664071
# [200]	training's binary_logloss: 0.0660748
# [250]	training's binary_logloss: 0.0658134
# [300]	training's binary_logloss: 0.0656018
# [350]	training's binary_logloss: 0.065412
# [400]	training's binary_logloss: 0.0652294
# [450]	training's binary_logloss: 0.0650547
# [500]	training's binary_logloss: 0.0648963
# 0.037756352252505024

# %%
test_data['predicted_score'] = bst.predict(test_data[features])
ctr = test_data.groupby(['hour'])['predicted_score'].mean().reset_index().rename(columns={0: 'ctr'})
ctr
# Out:
#     hour  predicted_score
# 0     12         0.043579
# 1     13         0.042940
# 2     14         0.042111
# 3     15         0.042799
# 4     16         0.043290
# 5     17         0.044002
# 6     18         0.043936
# 7     19         0.043686
# 8     20         0.037848
# 9     21         0.031661
# 10    22         0.026631
# 11    23         0.023129

# %%
cnt = test_data.groupby(['hour'])['predicted_score'].sum().reset_index().rename(columns={0: 'ctr'})
cnt
# Out:
#     hour  predicted_score
# 0     12      3637.002171
# 1     13      3924.773135
# 2     14      3936.142016
# 3     15      3904.629794
# 4     16      3713.780702
# 5     17      3265.279252
# 6     18      3335.432108
# 7     19      4426.603065
# 8     20      4867.479316
# 9     21      4410.533529
# 10    22      3633.878288
# 11    23      2342.102760

# %%
importance = pd.DataFrame(bst.feature_importance())
importance.columns = ['importance_20']
features = pd.DataFrame(features)
features.columns = ['features_20']
pd.set_option('max_rows',500)
merge = features.join(importance)
merge = merge.sort_values(by=['importance_20'], ascending=False).reset_index()
merge
# Out:
#      index                                        features_20  importance_20
# 0        4                                   item_sales_level            294
# 1      142                                    hour_smooth_CTR            189
# 2       58                   user_click_time_gap_after_global            188
# 3      151                  user_gender_id_item_id_smooth_CTR            152
# 4      150                  user_gender_id_shop_id_smooth_CTR            146
# 5       53                          user_click_time_gap_after            139
# 6      156              user_occupation_id_shop_id_smooth_CTR            131
# 7       91   user_category2_label_click_time_gap_after_global            120
# 8      157              user_occupation_id_item_id_smooth_CTR            113
# 9       10                                    user_star_level            111
# 10     128          user_age_level_category2_label_smooth_CTR            109
# 11      56                    user_click_interval_last_global            107
# 12      17                                shop_score_delivery            103
# 13     154                  user_age_level_item_id_smooth_CTR             98
# 14      14                          shop_review_positive_rate             95
# 15       5                               item_collected_level             94
# 16     171                                 item_id_click_hour             93
# 17     152            user_gender_id_item_brand_id_smooth_CTR             92
# 18       2                                       item_city_id             89
# 19      19                                                day             87
# 20      44                             shop_id_click_day_mean             86
# 21      61       user_category2_label_last_click_interval_day             84
# 22      18                             shop_score_description             82
# 23      45                             item_id_click_day_mean             81
# 24      41                             user_id_click_day_mean             80
# 25      12                                            shop_id             79
# 26     176                                 shop_id_click_hour             77
# 27     158        user_occupation_id_item_brand_id_smooth_CTR             77
# 28       0                                            item_id             77
# 29      13                              shop_review_num_level             76
# 30     211       user_occupation_id_user_star_level_click_day             75
# 31     153                  user_age_level_shop_id_smooth_CTR             71
# 32     177                item_property_topic_k_15_click_hour             70
# 33       1                                      item_brand_id             67
# 34     127         user_age_level_item_price_level_smooth_CTR             64
# 35     167                          context_page_id_click_day             63
# 36      63      user_category2_label_click_time_gap_after_day             63
# 37     159                 user_star_level_shop_id_smooth_CTR             62
# 38      16                                 shop_score_service             62
# 39     123                              category_predict_rank             61
# 40      99          user_item_id_click_time_gap_before_global             61
# 41     155            user_age_level_item_brand_id_smooth_CTR             61
# 42      51                       user_click_interval_last_day             61
# 43     175                         context_page_id_click_hour             59
# 44     160                 user_star_level_item_id_smooth_CTR             59
# 45      50                      user_click_interval_first_day             58
# 46     141      user_occupation_id_user_star_level_smooth_CTR             58
# 47     229                  shop_review_positive_rate_bin_day             58
# 48     138          user_gender_id_user_star_level_smooth_CTR             56
# 49      55                   user_click_interval_first_global             56
# 50      15                                    shop_star_level             56
# 51       6                                      item_pv_level             55
# 52     213                   user_gender_id_item_id_click_day             53
# 53      23                     user_category2_label_click_day             52
# 54     130     user_occupation_id_item_price_level_smooth_CTR             52
# 55       8                                     user_age_level             52
# 56      94   user_category3_label_click_time_gap_after_global             51
# 57     215                   user_age_level_shop_id_click_day             50
# 58     163                                  item_id_click_day             50
# 59     174                         category3_label_click_hour             49
# 60     125          user_gender_id_category2_label_smooth_CTR             49
# 61     134         user_star_level_category2_label_smooth_CTR             49
# 62     234                                category2_label_day             48
# 63     208           user_gender_id_user_star_level_click_day             47
# 64     140          user_age_level_user_star_level_smooth_CTR             47
# 65      98                     user_item_id_click_rank_global             46
# 66     161           user_star_level_item_brand_id_smooth_CTR             46
# 67     173                         category2_label_click_hour             46
# 68     210           user_age_level_user_star_level_click_day             45
# 69     212                   user_gender_id_shop_id_click_day             44
# 70     100           user_item_id_click_time_gap_after_global             44
# 71      52                         user_click_time_gap_before             43
# 72     203         user_star_level_item_price_level_click_day             42
# 73     133        user_star_level_item_price_level_smooth_CTR             42
# 74      60      user_category2_label_first_click_interval_day             42
# 75     169                 item_property_topic_k_15_click_day             42
# 76     216                   user_age_level_item_id_click_day             42
# 77     165                          category2_label_click_day             41
# 78     233                     shop_score_description_bin_day             41
# 79     162                                  user_id_click_day             41
# 80     149             user_id_item_price_level_bin_history_I             40
# 81     131      user_occupation_id_category2_label_smooth_CTR             40
# 82     218               user_occupation_id_shop_id_click_day             40
# 83     219               user_occupation_id_item_id_click_day             39
# 84     198           user_age_level_category2_label_click_day             39
# 85     137       user_gender_id_user_occupation_id_smooth_CTR             39
# 86      43                     category3_label_click_day_mean             39
# 87     168                                  shop_id_click_day             39
# 88     146                  user_id_category3_label_history_I             38
# 89      62     user_category2_label_click_time_gap_before_day             38
# 90     236                       item_property_topic_k_15_day             37
# 91     122                                       property_sim             37
# 92     186                  user_category2_label_future_15min             36
# 93     225                           item_sales_level_bin_day             36
# 94     136           user_gender_id_user_age_level_smooth_CTR             36
# 95     204          user_star_level_category2_label_click_day             36
# 96     143                          user_id_item_id_history_I             35
# 97      20                                    category2_label             35
# 98      75              user_item_id_first_click_interval_day             35
# 99     111                              item_property_topic_4             34
# 100    135         user_star_level_category3_label_smooth_CTR             34
# 101     42                     category2_label_click_day_mean             34
# 102    206            user_gender_id_user_age_level_click_day             33
# 103    231                         shop_score_service_bin_day             33
# 104    195           user_gender_id_category2_label_click_day             32
# 105    232                        shop_score_delivery_bin_day             32
# 106    178                        user_item_id_continue_click             32
# 107    110                              item_property_topic_3             32
# 108    164                            item_brand_id_click_day             32
# 109    126          user_gender_id_category3_label_smooth_CTR             32
# 110     57                  user_click_time_gap_before_global             32
# 111    106  user_item_property_topic_k_15_click_time_gap_a...             32
# 112    170                                 user_id_click_hour             31
# 113    114                              item_property_topic_7             31
# 114    121                             item_property_topic_14             31
# 115    244                 user_age_level_category3_label_day             30
# 116    214             user_gender_id_item_brand_id_click_day             30
# 117     28                     user_context_page_id_click_day             30
# 118    220         user_occupation_id_item_brand_id_click_day             30
# 119    228                      shop_review_num_level_bin_day             30
# 120     46                       item_brand_id_click_day_mean             30
# 121    243                 user_age_level_category2_label_day             30
# 122    200      user_occupation_id_item_price_level_click_day             30
# 123     68      user_category3_label_click_time_gap_after_day             29
# 124     78              user_item_id_click_time_gap_after_day             29
# 125    194          user_gender_id_item_price_level_click_day             29
# 126    201       user_occupation_id_category2_label_click_day             29
# 127     89             user_category2_label_click_rank_global             28
# 128     37                    user_context_page_id_click_hour             28
# 129     93  user_category3_label_click_time_gap_before_global             28
# 130    172                           item_brand_id_click_hour             28
# 131    124         user_gender_id_item_price_level_smooth_CTR             27
# 132    166                          category3_label_click_day             27
# 133    245        user_age_level_item_property_topic_k_15_day             26
# 134    129          user_age_level_category3_label_smooth_CTR             26
# 135    209        user_age_level_user_occupation_id_click_day             26
# 136    205          user_star_level_category3_label_click_day             26
# 137     85  user_item_property_topic_k_15_first_click_inte...             26
# 138    196           user_gender_id_category3_label_click_day             26
# 139    237                                context_page_id_day             26
# 140     65      user_category3_label_first_click_interval_day             26
# 141    105  user_item_property_topic_k_15_click_time_gap_b...             25
# 142     77             user_item_id_click_time_gap_before_day             25
# 143    239                 user_gender_id_category2_label_day             25
# 144     47                     context_page_id_click_day_mean             25
# 145    227                              item_pv_level_bin_day             24
# 146    197          user_age_level_item_price_level_click_day             24
# 147    199           user_age_level_category3_label_click_day             24
# 148     67     user_category3_label_click_time_gap_before_day             24
# 149    145                  user_id_category2_label_history_I             24
# 150    139       user_age_level_user_occupation_id_smooth_CTR             24
# 151     90  user_category2_label_click_time_gap_before_global             24
# 152     66       user_category3_label_last_click_interval_day             24
# 153    230                            shop_star_level_bin_day             23
# 154    242            user_age_level_item_price_level_bin_day             23
# 155    182                user_category3_label_continue_click             23
# 156    249    user_occupation_id_item_property_topic_k_15_day             22
# 157    112                              item_property_topic_5             22
# 158    118                             item_property_topic_11             22
# 159    226                       item_collected_level_bin_day             22
# 160     24                     user_category3_label_click_day             22
# 161    116                              item_property_topic_9             22
# 162    217             user_age_level_item_brand_id_click_day             22
# 163    246        user_occupation_id_item_price_level_bin_day             21
# 164     54                             user_click_rank_global             21
# 165    247             user_occupation_id_category2_label_day             21
# 166    207        user_gender_id_user_occupation_id_click_day             21
# 167    119                             item_property_topic_12             20
# 168    120                             item_property_topic_13             20
# 169    241        user_gender_id_item_property_topic_k_15_day             20
# 170    181                user_category2_label_continue_click             20
# 171     83        user_item_brand_id_click_time_gap_after_day             19
# 172    132      user_occupation_id_category3_label_smooth_CTR             19
# 173    115                              item_property_topic_8             19
# 174    117                             item_property_topic_10             19
# 175    102    user_item_brand_id_click_time_gap_before_global             19
# 176     88  user_item_property_topic_k_15_click_time_gap_a...             19
# 177     32                    user_category2_label_click_hour             18
# 178     11                                    context_page_id             18
# 179    107                              item_property_topic_0             18
# 180     86  user_item_property_topic_k_15_last_click_inter...             18
# 181     26                             user_item_id_click_day             17
# 182     38               user_item_price_level_bin_click_hour             17
# 183     96          user_shop_id_click_time_gap_before_global             17
# 184     22                           item_property_topic_k_15             17
# 185    235                                category3_label_day             17
# 186     21                                    category3_label             17
# 187      3                                   item_price_level             16
# 188    202       user_occupation_id_category3_label_click_day             16
# 189    252              user_age_level_user_occupation_id_day             16
# 190     70              user_shop_id_first_click_interval_day             15
# 191    108                              item_property_topic_1             14
# 192    113                              item_property_topic_6             14
# 193    224                           item_price_level_bin_day             14
# 194    179                  user_item_brand_id_continue_click             14
# 195     33                    user_category3_label_click_hour             13
# 196     81         user_item_brand_id_last_click_interval_day             13
# 197     87  user_item_property_topic_k_15_click_time_gap_b...             13
# 198    109                              item_property_topic_2             13
# 199    147                          user_id_shop_id_history_I             13
# 200    248             user_occupation_id_category3_label_day             13
# 201    187                  user_category3_label_future_15min             13
# 202    185           user_item_price_level_bin_continue_click             12
# 203    238            user_gender_id_item_price_level_bin_day             12
# 204     29                user_item_price_level_bin_click_day             12
# 205    183       user_item_property_topic_k_15_continue_click             11
# 206     76               user_item_id_last_click_interval_day             11
# 207     30                user_item_sales_level_bin_click_day             11
# 208    184           user_item_sales_level_bin_continue_click             11
# 209    148             user_id_item_sales_level_bin_history_I             11
# 210     48                                user_click_rank_day             11
# 211    189                          user_item_id_future_15min             10
# 212     80        user_item_brand_id_first_click_interval_day             10
# 213     31            user_item_property_topic_k_15_click_day             10
# 214    103     user_item_brand_id_click_time_gap_after_global             10
# 215     25                             user_shop_id_click_day             10
# 216     27                       user_item_brand_id_click_day             10
# 217     74                        user_item_id_click_rank_day              9
# 218    101               user_item_brand_id_click_rank_global              9
# 219    250                  user_gender_id_user_age_level_day              9
# 220     69                        user_shop_id_click_rank_day              8
# 221     72             user_shop_id_click_time_gap_before_day              8
# 222     73              user_shop_id_click_time_gap_after_day              8
# 223    104    user_item_property_topic_k_15_click_rank_global              8
# 224     97           user_shop_id_click_time_gap_after_global              8
# 225     49                           user_click_true_rank_day              8
# 226     82       user_item_brand_id_click_time_gap_before_day              8
# 227    240                 user_gender_id_category3_label_day              8
# 228     34                            user_shop_id_click_hour              7
# 229    191         user_item_property_topic_k_15_future_15min              7
# 230    222                                 user_age_level_day              7
# 231    192             user_item_sales_level_bin_future_15min              7
# 232    188                          user_shop_id_future_15min              7
# 233     36                      user_item_brand_id_click_hour              7
# 234    180                        user_shop_id_continue_click              6
# 235    251              user_gender_id_user_occupation_id_day              6
# 236     59                user_category2_label_click_rank_day              6
# 237     39               user_item_sales_level_bin_click_hour              5
# 238     35                            user_item_id_click_hour              4
# 239      7                                     user_gender_id              4
# 240    144                    user_id_item_brand_id_history_I              4
# 241     40           user_item_property_topic_k_15_click_hour              4
# 242     92             user_category3_label_click_rank_global              4
# 243     95                     user_shop_id_click_rank_global              4
# 244     64                user_category3_label_click_rank_day              4
# 245     71               user_shop_id_last_click_interval_day              4
# 246      9                                 user_occupation_id              3
# 247    193             user_item_price_level_bin_future_15min              3
# 248     84       user_item_property_topic_k_15_click_rank_day              2
# 249     79                  user_item_brand_id_click_rank_day              2
# 250    223                             user_occupation_id_day              1
# 251    190                    user_item_brand_id_future_15min              0
# 252    221                                 user_gender_id_day              0
